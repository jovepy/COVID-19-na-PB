# %%
# !pip install -U kaleido
from datetime import timedelta, date
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import pandas as pd
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
inicio_analise = (date.today()-timedelta(7)).strftime('%Y-%m-%d')
final_analise = (date.today()-timedelta(1)).strftime('%Y-%m-%d')
inicio_passada = (date.today()-timedelta(14)).strftime('%Y-%m-%d')
final_passada = inicio_analise

# %%
base = pd.read_excel('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Base_Permanente/dasboard_covid.xlsx',index_col=0)
ocupacao = pd.read_excel('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Base_Permanente/leitosadultos.xlsx',index_col=0)

# %%
base.index = pd.to_datetime(base.index)
ocupacao.index = pd.to_datetime(ocupacao.index)

# %%
fig = make_subplots(rows=2, cols=1, 
                    start_cell="bottom-left",
                   subplot_titles=('Ocupação das UTIs','Quantidade de UTIs')
                   ) #ocupação = nº de pacientes no leito/ leitos existentes
                   #Para suavização utilizouce a média simples, pois achei a responsividade maior q a exponencial




fig.add_trace(go.Scatter(
    x=ocupacao['utiadGJP'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['utiadGJP'].ewm(span=13, adjust=False).mean().dropna())*100,
    line=dict(color='Purple'),
    name= 'João Pessoa',
    showlegend=True,
    legendgroup= 'João Pessoa',
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=ocupacao['utiadcg'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['utiadcg'].ewm(span=13, adjust=False).mean().dropna())*100,
    line=dict(color='RoyalBlue'),
    name= 'Campina Grande Adultos',
    showlegend=True,
    legendgroup= 'Campina Grande',
), row=1, col=1)


fig.add_trace(go.Scatter(
    x=base['ocup_uti'].rolling(13).mean().dropna().index,
    y=(base['ocup_uti'].ewm(span=13, adjust=False).mean().dropna())*100,
    name= 'Paraíba',
    showlegend=True,
    legendgroup= 'Paraíba',
    line=dict(color='Seagreen',
              dash="dashdot"),
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=ocupacao['utiadpb'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['utiadpb'].ewm(span=13, adjust=False).mean().dropna())*100,
    name= 'Paraíba Adultos',
    showlegend=True,
    legendgroup= 'Paraíba',
    line=dict(color='Seagreen'),
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=ocupacao['utiadSERTAO'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['utiadSERTAO'].ewm(span=13, adjust=False).mean().dropna())*100,
    name= 'Sertão adultos ',
    showlegend=True,
    legendgroup= 'Sertão',
    line=dict(color='Orange')), row=1, col=1)

fig.add_trace(go.Scatter(
    x=base['qnt_uti'].index,
    y=base['qnt_uti'],
    name= 'UTIs existentes',
    showlegend=True,
    fill='tozeroy',
    line=dict(color='Darkred')), row=2, col=1)

fig.update_layout(
    template="plotly_white",
    legend_orientation="h",
    legend=dict(x=0, y=-.1),
    width=800,
    height=600,
    font=dict(
        family="Times New Roman",
        size=13,
        color="DimGray"
    ))
    


fig.update_yaxes(title_text="Porcentagem (%)" , nticks=5,  row=1, col=1,showgrid=False, showline=True ,showticklabels=True)
fig.update_yaxes(title_text="Porcentagem (%)" , nticks=5, row=2, col=1,showgrid=False, showline=True ,showticklabels=True)

fig.update_xaxes( nticks=20,  row=1, col=1,showgrid=False, showline=True ,showticklabels=True)
fig.update_xaxes( nticks=20, row=2, col=1,showgrid=False, showline=True ,showticklabels=True,)

fig.show()
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/UTI.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fd2fa1ce-6306-4bfb-af78-9a659816d7dd" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd2fa1ce-6306-4bfb-af78-9a659816d7dd")) {                    Plotly.newPlot(                        "fd2fa1ce-6306-4bfb-af78-9a659816d7dd",                        [{"legendgroup":"Jo\u00e3o Pessoa","line":{"color":"Purple"},"name":"Jo\u00e3o Pessoa","showlegend":true,"x":["2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-08T00:00:00","2020-08-09T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-15T00:00:00","2020-08-16T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-22T00:00:00","2020-08-23T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-29T00:00:00","2020-08-30T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-19T00:00:00","2020-09-20T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-26T00:00:00","2020-09-27T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-02T00:00:00","2020-10-03T00:00:00","2020-10-04T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-10T00:00:00","2020-10-11T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-17T00:00:00","2020-10-18T00:00:00","2020-10-19T00:00:00" ...

# %%
fig = make_subplots(rows=2, cols=1, 
                    start_cell="bottom-left",
                   subplot_titles=('Ocupação das Enfermarias','Quantidade de Enfermarias')
                   ) #ocupação = nº de pacientes no leito/ leitos existentes
                   #Para suavização utilizouce a média simples, pois achei a responsividade maior q a exponencial




fig.add_trace(go.Scatter(
    x=ocupacao['enfadGJP'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['enfadGJP'].ewm(span=13, adjust=False).mean().dropna())*100,
    line=dict(color='Purple'),
    name= 'João Pessoa',
    showlegend=True,
    legendgroup= 'João Pessoa',
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=ocupacao['utiadcg'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['utiadcg'].ewm(span=13, adjust=False).mean().dropna())*100,
    line=dict(color='RoyalBlue'),
    name= 'Campina Grande Adultos',
    showlegend=True,
    legendgroup= 'Campina Grande',
), row=1, col=1)


fig.add_trace(go.Scatter(
    x=base['ocup_enf'].rolling(13).mean().dropna().index,
    y=(base['ocup_enf'].ewm(span=13, adjust=False).mean().dropna())*100,
    name= 'Paraíba',
    showlegend=True,
    legendgroup= 'Paraíba',
    line=dict(color='Seagreen',
              dash="dashdot"),
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=ocupacao['enfadpb'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['enfadpb'].ewm(span=13, adjust=False).mean().dropna())*100,
    name= 'Paraíba Adultos',
    showlegend=True,
    legendgroup= 'Paraíba',
    line=dict(color='Seagreen'),
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=ocupacao['enfadSERTAO'].ewm(span=13, adjust=False).mean().dropna().index,
    y=(ocupacao['enfadSERTAO'].ewm(span=13, adjust=False).mean().dropna())*100,
    name= 'Sertão adultos ',
    showlegend=True,
    legendgroup= 'Sertão',
    line=dict(color='Orange')), row=1, col=1)

fig.add_trace(go.Scatter(
    x=base['qnt_enf'].index,
    y=base['qnt_enf'],
    name= 'Enfermarias existentes',
    showlegend=True,
    fill='tozeroy',
    line=dict(color='Darkred')), row=2, col=1)

fig.update_layout(
    template="plotly_white",
    legend_orientation="h",
    legend=dict(x=0, y=-.1),
    width=800,
    height=600,
    font=dict(
        family="Times New Roman",
        size=13,
        color="DimGray"
    ))
    


fig.update_yaxes(title_text="Porcentagem (%)" , nticks=5,  row=1, col=1,showgrid=False, showline=True ,showticklabels=True)
fig.update_yaxes(title_text="Porcentagem (%)" , nticks=5, row=2, col=1,showgrid=False, showline=True ,showticklabels=True)

fig.update_xaxes( nticks=20,  row=1, col=1,showgrid=False, showline=True ,showticklabels=True)
fig.update_xaxes( nticks=20, row=2, col=1,showgrid=False, showline=True ,showticklabels=True,)

fig.show()
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/ENFERMARIA.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c7501c08-27ca-4780-8e4d-87a74f7154d1" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7501c08-27ca-4780-8e4d-87a74f7154d1")) {                    Plotly.newPlot(                        "c7501c08-27ca-4780-8e4d-87a74f7154d1",                        [{"legendgroup":"Jo\u00e3o Pessoa","line":{"color":"Purple"},"name":"Jo\u00e3o Pessoa","showlegend":true,"x":["2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-08T00:00:00","2020-08-09T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-15T00:00:00","2020-08-16T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-22T00:00:00","2020-08-23T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-29T00:00:00","2020-08-30T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-19T00:00:00","2020-09-20T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-26T00:00:00","2020-09-27T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-02T00:00:00","2020-10-03T00:00:00","2020-10-04T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-10T00:00:00","2020-10-11T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-17T00:00:00","2020-10-18T00:00:00","2020-10-19T00:00:00" ...

# %%
def agregar_mensalmente_ocupação():
  arte_ocupação = pd.concat([ocupacao,base[['ocup_enf','ocup_uti']]],axis=1)
  arte_ocupação.index = arte_ocupação.index.strftime('%Y-%m')
  arte_ocupação = arte_ocupação.groupby(by='data').mean()
  return(arte_ocupação)

# %%
arte_ocupação_utis_mensal = agregar_mensalmente_ocupação()
arte_ocupação_utis_mensal = arte_ocupação_utis_mensal[['utiadpb', 'utiadGJP', 'utiadcg','utiadSERTAO', 'ocup_uti']]
arte_ocupação_utis_mensal.columns = ['Adultos da PB', 'Adultos de João Pessoa','Adultos de Campina Grande','Adultos do Sertão','Paraíba Agregado']

# %%
arte_ocupação_enf_mensal = agregar_mensalmente_ocupação()
arte_ocupação_enf_mensal = arte_ocupação_enf_mensal[['enfadpb', 'enfadGJP', 'enfadcg', 'enfadSERTAO', 'ocup_enf']]
arte_ocupação_enf_mensal.columns = ['Adultos da PB', 'Adultos de João Pessoa','Adultos de Campina Grande','Adultos do Sertão','Paraíba Agregado']

# %%
def gerar_gráfico_ocupação(df=pd.DataFrame(),coluna=str,titulo=str):

  fig = go.Figure()
  legendabr = []
  for data in df.index:
    aux = pd.to_datetime(data).strftime('%m-%Y')
    legendabr.append(aux)
    if data == df.index[-1]:
      fig.add_trace(go.Bar(
          x=[data],
          y=[df.loc[data][coluna]], 
          marker_color= 'DarkOrange',
          showlegend=False      
      ))
    else:
      fig.add_trace(go.Bar(
          x=[data],
          y=[df.loc[data][coluna]], 
          marker_color= 'Silver',
          showlegend=False      
      ))

    fig.add_annotation(x=data, y=(df.loc[data][coluna]+.03),
              text= str(round(df.loc[data][coluna]*100,2))+'%',
              showarrow=False,
              )

  fig.update_layout(legend_orientation='h',
                    template='plotly_white',
                    width=1300,
                    height=600,
                    title=titulo)

  fig.update_xaxes(type='category',nticks=len(arte_ocupação_utis_mensal))
  fig.update_yaxes(showgrid=False, showline=False ,showticklabels=False,type='linear')

  
  return(fig.show())

# %%
novo_grupo =[]
for grupo in arte_ocupação_enf_mensal.index[-7:]:
  novo_grupo.append(pd.to_datetime(grupo).strftime('%m/%Y'))
grupos=novo_grupo

colors = ['silver',] * (len(grupos))
colors[-1] = 'Darkorange'

fig = go.Figure()
for coluna in ['Adultos da PB', 'Adultos de João Pessoa','Adultos de Campina Grande','Adultos do Sertão','Paraíba Agregado']:
  fig.add_trace(go.Bar(
      x=grupos,
      y=arte_ocupação_enf_mensal[coluna][-7:],
      text=(round(100*arte_ocupação_enf_mensal[coluna][-7:])),
      textposition='auto',
      name=coluna,
      showlegend=False,
      marker_color=colors,
  ))

fig.add_trace(go.Scatter(x=novo_grupo, y=[arte_ocupação_enf_mensal['Paraíba Agregado'].mean()]*(len(arte_ocupação_enf_mensal.index[-7:])),
                    mode='lines+text',
                    name='lines',
                    showlegend=False,
                    text= ['Média de ocupação das enfermarias '+ str(int(round(100*arte_ocupação_enf_mensal['Paraíba Agregado'].mean(),0))) +'%']+(1-len(arte_ocupação_enf_mensal.index))*[' '],
                    textposition="bottom right",
                    textfont=dict(family="Arial",size=21,color="RoyalBlue"),
                    line=dict(color='RoyalBlue',dash='dot', width=1)))





# Change the bar mode

fig.update_layout(barmode='group',
                  template='plotly_white',
                  width=1200,
                  height=500,
                  title='Ocupação médias das enfermarias de COVID-19')

fig.update_xaxes(type='category',nticks=len(arte_ocupação_enf_mensal))
fig.update_yaxes(showgrid=False, showline=True ,showticklabels=False, nticks=5 ,type='linear')


fig.show()
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/OCUP_MEDIA_ENF.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8d405109-262c-48d9-8ffd-e024b14ec2c8" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d405109-262c-48d9-8ffd-e024b14ec2c8")) {                    Plotly.newPlot(                        "8d405109-262c-48d9-8ffd-e024b14ec2c8",                        [{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos da PB","showlegend":false,"text":[19.0,13.0,11.0,9.0,20.0,45.0,15.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.19263333333333332,0.1329032258064516,0.11366666666666667,0.09161290322580645,0.1964516129032258,0.44571428571428573,0.14666666666666667],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos de Jo\u00e3o Pessoa","showlegend":false,"text":[21.0,17.0,13.0,15.0,20.0,71.0,24.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.20833333333333334,0.16741935483870968,0.13033333333333333,0.1503225806451613,0.19903225806451613,0.7053571428571429,0.23888888888888887],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos de Campina Grande","showlegend":false,"text":[20.0,11.0,9.0,2.0,14.0,30.0,9.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.20400000000000001,0.10774193548387097,0.09033333333333333,0.023870967741935485,0.1435483870967742,0.2967142857142857,0.08888888888888889],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos do Sert\u00e3o","showlegend":false,"text":[16.0,12.0,18.0,10.0,30.0,39.0,13.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.16266666666666665,0.11935483870967742,0.177,0.09645161290322582,0.3041935483870968,0.3885714285714286,0.13],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Para\u00edba Agregado","showlegend":false,"text":[20.0,12.0,11.0,9.0,20.0,58.0,84.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.196,0.11838709677419354,0.11066666666666668,0.08774193548387098,0.1964516129032258,0.5828571428571429,0.8382352941176471],"type":"bar"},{"line":{"color":"RoyalBlue","dash":"dot","width":1},"mode":"lines+text","name":"lines","showlegend":false,"text":["M\u00e9dia de ocupa\u00e7\u00e3o das enfermarias 38%"],"textfont":{"color":"RoyalBlue","family":"Arial","size":21},"textposition":"bottom right","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.37980663036603135,0.37980663036603135,0.37980663036603135,0.37980663036603135,0.37980663036603135,0.37980663036603135,0.37980663036603135],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks ...

# %%
novo_grupo =[]
for grupo in arte_ocupação_utis_mensal.index[-7:]:
  novo_grupo.append(pd.to_datetime(grupo).strftime('%m/%Y'))
grupos=novo_grupo

colors = ['silver',] * (len(grupos))
colors[-1] = 'Darkorange'

fig = go.Figure()
for coluna in ['Adultos da PB', 'Adultos de João Pessoa','Adultos de Campina Grande','Adultos do Sertão','Paraíba Agregado']:
  fig.add_trace(go.Bar(
      x=grupos,
      y=arte_ocupação_utis_mensal[coluna][-7:],
      text=(round(100*arte_ocupação_utis_mensal[coluna][-7:])),
      textposition='auto',
      name=coluna,
      showlegend=False,
      marker_color=colors,
  ))

fig.add_trace(go.Scatter(x=novo_grupo, y=[arte_ocupação_utis_mensal['Paraíba Agregado'].mean()]*(len(arte_ocupação_utis_mensal.index[-7:])),
                    mode='lines+text',
                    name='lines',
                    showlegend=False,
                    text= ['Média de ocupação das UTIs '+ str(int(round(100*arte_ocupação_utis_mensal['Paraíba Agregado'].mean(),0))) +'%']+(1-len(arte_ocupação_utis_mensal.index))*[' '],
                    textposition="bottom right",
                    textfont=dict(family="Arial",size=21,color="RoyalBlue"),
                    line=dict(color='RoyalBlue',dash='dot', width=1)))





# Change the bar mode

fig.update_layout(barmode='group',
                  template='plotly_white',
                  width=1200,
                  height=500,
                  title='Ocupação média mensal das UTIs de COVID-19')

fig.update_xaxes(type='category',nticks=len(arte_ocupação_utis_mensal))
fig.update_yaxes(showgrid=False, showline=True ,showticklabels=False, nticks=5 ,type='linear')


fig.show()
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/OCUP_MEDIA_UTI.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f5a766a9-f4b7-4a7d-8893-337c34cb5c89" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5a766a9-f4b7-4a7d-8893-337c34cb5c89")) {                    Plotly.newPlot(                        "f5a766a9-f4b7-4a7d-8893-337c34cb5c89",                        [{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos da PB","showlegend":false,"text":[20.0,24.0,23.0,17.0,27.0,53.0,31.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.20033333333333334,0.23580645161290323,0.22886666666666666,0.17483870967741935,0.272258064516129,0.5303571428571429,0.31444444444444447],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos de Jo\u00e3o Pessoa","showlegend":false,"text":[15.0,24.0,29.0,31.0,38.0,70.0,40.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.151,0.2438709677419355,0.2936666666666667,0.31193548387096776,0.3780645161290323,0.6978571428571428,0.4011111111111111],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos de Campina Grande","showlegend":false,"text":[23.0,20.0,13.0,4.0,14.0,41.0,20.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.23433333333333334,0.20419354838709677,0.13433333333333333,0.03596774193548387,0.14322580645161292,0.40857142857142853,0.19555555555555557],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Adultos do Sert\u00e3o","showlegend":false,"text":[29.0,31.0,38.0,24.0,38.0,50.0,43.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.29133333333333333,0.31451612903225806,0.38166666666666665,0.23870967741935484,0.3809677419354839,0.5017857142857143,0.4255555555555556],"type":"bar"},{"marker":{"color":["silver","silver","silver","silver","silver","silver","Darkorange"]},"name":"Para\u00edba Agregado","showlegend":false,"text":[19.0,21.0,23.0,18.0,27.0,52.0,70.0],"textposition":"auto","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.18733333333333332,0.2132258064516129,0.22933333333333333,0.18,0.272258064516129,0.5221428571428571,0.6994117647058824],"type":"bar"},{"line":{"color":"RoyalBlue","dash":"dot","width":1},"mode":"lines+text","name":"lines","showlegend":false,"text":["M\u00e9dia de ocupa\u00e7\u00e3o das UTIs 47%"],"textfont":{"color":"RoyalBlue","family":"Arial","size":21},"textposition":"bottom right","x":["09/2021","10/2021","11/2021","12/2021","01/2022","02/2022","03/2022"],"y":[0.46734515854027436,0.46734515854027436,0.46734515854027436,0.46734515854027436,0.46734515854027436,0.46734515854027436,0.46734515854027436],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0," ...

# %%
arte_hospitalzados = base[['hospitalizados_uti' ,	'hospitalizados_enf']]
arte_hospitalzados.columns = ['hospitalizados na uti','hospitalizados na enf']
arte_hospitalzados.index = arte_hospitalzados.index.strftime('%Y-%m')
arte_hospitalzados = arte_hospitalzados.groupby(by='data').mean()


fig = go.Figure() 

fig.add_trace(go.Bar(
        y=arte_hospitalzados['hospitalizados na enf'].index,
        x=round(arte_hospitalzados['hospitalizados na enf'],0),
        name='Hospitalizados nas enfermarias',
        orientation='h',
        text=round(arte_hospitalzados['hospitalizados na enf'],0),
        textposition='auto',
        marker=dict(
            color='CornflowerBlue',
            line=dict(color='silver', width=2)),
        showlegend=False,
    ))

fig.add_trace(go.Bar(
        y=arte_hospitalzados['hospitalizados na uti'].index,
        x=round(arte_hospitalzados['hospitalizados na uti'],0),
        text=round(arte_hospitalzados['hospitalizados na uti'],0),
        textposition='auto',
        name='Hospitalizados nas utis',
        orientation='h',
        marker=dict(
            color='DarkOrange',
            line=dict(color='silver', width=4)),
        showlegend=False,
    ))

fig.update_layout(
    template='plotly_white',
    title='Como os hospitalizados se distribuem?',
    legend_orientation="v",
    legend=dict(x=1, y=1),
    width=800,
    height=800,
    font=dict(
        family="Times New Roman",
        size=15,
        color="DimGray"
    ),
    barmode='relative'
)

fig.update_xaxes(showgrid=False, showline=True, showticklabels=True,type='linear')





fig.add_annotation(x=800, y=arte_hospitalzados['hospitalizados na uti'].index[0],
            text="Pacientes nas Enfermarias",
            showarrow=False,
            arrowhead=1,
            font=dict(
            family="Times",
            size=18,
            color="CornflowerBlue"
            ))

fig.add_annotation(x=800, y=arte_hospitalzados['hospitalizados na uti'].index[1],
            text="Pacientes nas UTIs",
            showarrow=False,
            arrowhead=1,
            font=dict(
            family="Times",
            size=18,
            color="DarkOrange"
            ),)


fig.add_annotation(x=800, y=arte_hospitalzados['hospitalizados na uti'].index[2],
            text="Total de hospitalizados",
            showarrow=False,
            arrowhead=1,
            font=dict(
            family="Times",
            size=18,
            color="Silver"
            ),)

fig.show()
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/DISTRIBUICAO_HOSP.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b7e749ed-2c09-4656-9fc7-7580dbf0be86" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7e749ed-2c09-4656-9fc7-7580dbf0be86")) {                    Plotly.newPlot(                        "b7e749ed-2c09-4656-9fc7-7580dbf0be86",                        [{"marker":{"color":"CornflowerBlue","line":{"color":"silver","width":2}},"name":"Hospitalizados nas enfermarias","orientation":"h","showlegend":false,"text":[225.0,288.0,234.0,187.0,141.0,123.0,129.0,168.0,188.0,226.0,391.0,383.0,453.0,450.0,232.0,129.0,117.0,58.0,49.0,39.0,89.0,272.0,337.0],"textposition":"auto","x":[225.0,288.0,234.0,187.0,141.0,123.0,129.0,168.0,188.0,226.0,391.0,383.0,453.0,450.0,232.0,129.0,117.0,58.0,49.0,39.0,89.0,272.0,337.0],"y":["2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"type":"bar"},{"marker":{"color":"DarkOrange","line":{"color":"silver","width":4}},"name":"Hospitalizados nas utis","orientation":"h","showlegend":false,"text":[164.0,220.0,196.0,149.0,114.0,100.0,109.0,158.0,156.0,171.0,367.0,357.0,368.0,405.0,226.0,117.0,77.0,71.0,69.0,54.0,82.0,143.0,168.0],"textposition":"auto","x":[164.0,220.0,196.0,149.0,114.0,100.0,109.0,158.0,156.0,171.0,367.0,357.0,368.0,405.0,226.0,117.0,77.0,71.0,69.0,54.0,82.0,143.0,168.0],"y":["2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#460 ...

# %%
fig = make_subplots(rows=2, cols=2, 
                    start_cell="bottom-left",
                   subplot_titles=("Hospitalizados e sua distribuição",
                                   "Média móvel exponencial 13 dias",
                                   "Taxa de Casos Graves hospitalizados",
                                   'Média Móvel Exponencial 13 dias')
                                   
)

fig.add_trace(go.Scatter(
    x=base['hospitalizados_enf'].index,
    y=base['hospitalizados_enf'],
    name= 'Hospitalizados nas Enfermarias',
    showlegend=True,
    legendgroup= 'Enfermaria',
    line=dict(color='CornflowerBlue'),
    line_color = 'CornflowerBlue'# this sets its legend entry
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=base['hospitalizados_enf'].ewm(span=13, adjust=False).mean().index,
    y=base['hospitalizados_enf'].ewm(span=13, adjust=False).mean(),
    name= 'MME Hospitalizados nas Enfermarias',
    showlegend=False,
    legendgroup= 'Enfermaria',
    line=dict(color='CornflowerBlue'),
    line_color = 'CornflowerBlue'# this sets its legend entry
), row=1, col=2)


fig.add_trace(go.Scatter(
    x= base['hospitalizados_uti'].index,
    y= base['hospitalizados_uti'],
    name= 'Hospitalizados nas UTIs',
    showlegend=True,
    legendgroup= 'UTI',
    line=dict(color='DarkOrange'),
    line_color ='Darkorange'
),row=1, col=1)

fig.add_trace(go.Scatter(
    x= base['hospitalizados_uti'].ewm(span=13, adjust=False).mean().index,
    y= base['hospitalizados_uti'].ewm(span=13, adjust=False).mean(),
    name= 'MME Hospitalizados nas UTIs',
    showlegend=False,
    legendgroup= 'UTI',
    line=dict(color='DarkOrange'),
    line_color='darkorange'
),row=1, col=2)


fig.add_trace(go.Scatter(
    x= base['total_hospitalizados'].index,
    y= base['total_hospitalizados'],
    name= 'Hospitalizados',
    line_color = 'silver',
    showlegend=True,
    legendgroup= 'Hospitalizados',
    line=dict(color='silver')
),row=1, col=1)

fig.add_trace(go.Scatter(
    x= base['total_hospitalizados'].ewm(span=13, adjust=False).mean().index,
    y= base['total_hospitalizados'].ewm(span=13, adjust=False).mean(),
    name= 'MME Hospitalizados',
    line_color = 'silver',
    showlegend=False,
    legendgroup= 'Hospitalizados',
    line=dict(color='silver'),
),row=1, col=2)

fig.add_trace(go.Scatter(
    x=base['taxa_graves_hosp'].index,
    y=base['taxa_graves_hosp'],
    name= 'Casos graves hospitalizados', # this sets its legend entry
    line_color = 'Darkred',
    showlegend=False,
    legendgroup= 'Casos Graves',
    line=dict(color='darkorange')
),row=2, col=1)
fig.add_trace(go.Scatter(
    x=base['taxa_graves_hosp'].ewm(span=13, adjust=False).mean().index,
    y=base['taxa_graves_hosp'].ewm(span=13, adjust=False).mean(),
    name= 'MME Casos graves hospitalizados',
    line_color = 'Darkred',
    showlegend=True,
    legendgroup= 'Casos Graves',
    line=dict(color='DarkOrange')
    # this sets its legend entry
),row=2, col=2)



fig.update_xaxes(title_text="Data", row=1, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_xaxes(title_text="Data", row=1, col=2,showgrid=False, showline=True, showticklabels=True)
fig.update_xaxes(title_text="Data", row=2, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_xaxes(title_text="Data", row=2, col=2,showgrid=False, showline=True, showticklabels=True)

fig.update_yaxes(title_text="N.º Hospitalizados", range=[0,base['total_hospitalizados'].max()+10], row=1, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_yaxes(title_text="", range=[0,base['total_hospitalizados'].max()+10], row=1, col=2,showgrid=False, showline=True, showticklabels=True)

fig.update_yaxes(title_text="% Casos Graves", showgrid=False, row=2, col=1)
fig.update_yaxes(title_text="", showgrid=False, row=2, col=2)

fig.update_layout(
    template="plotly_white",
    legend_orientation="h",
    legend=dict(x=0, y=-.2),
    width=800,
    height=800,
    font=dict(
        family="Times New Roman",
        size=13,
        color="DimGray"
    )
)

fig.show()
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/HOSPITALIZADOS.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0ec43a00-ebd6-4a65-9324-c9d765d4c83a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ec43a00-ebd6-4a65-9324-c9d765d4c83a")) {                    Plotly.newPlot(                        "0ec43a00-ebd6-4a65-9324-c9d765d4c83a",                        [{"legendgroup":"Enfermaria","line":{"color":"CornflowerBlue"},"name":"Hospitalizados nas Enfermarias","showlegend":true,"x":["2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-08T00:00:00","2020-08-09T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-15T00:00:00","2020-08-16T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-22T00:00:00","2020-08-23T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-29T00:00:00","2020-08-30T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-19T00:00:00","2020-09-20T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-26T00:00:00","2020-09-27T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-02T00:00:00","2020-10-03T00:00:00","2020-10-04T00:00:00","2020-10-05T00:00:00","2020 ...

# %%
fig = make_subplots(rows=3, cols=1, 
                    start_cell="bottom-left",
                   subplot_titles=('Hospitalizados','Enfermaria','UTI'
                                   )
                   )

fig.add_trace(
    go.Scatter(
        x=base.shift(30).dropna()['total_hospitalizados'].ewm(span=13, adjust=False).mean().index,
        y=base.shift(30).dropna()['total_hospitalizados'].ewm(span=13, adjust=False).mean(),
        name = 'Há 30 dias',
        showlegend=True,
        legendgroup= '30d',
        line=dict(color='darkorange'),
    ), row=1, col=1)

fig.add_trace(
    go.Bar(
        x=base['hospitalizados_enf'].loc[base['hospitalizados_enf'].shift(30).dropna().index].ewm(span=13, adjust=False).mean().index,
        y=base['hospitalizados_enf'].loc[base['hospitalizados_enf'].shift(30).dropna().index].ewm(span=13, adjust=False).mean(),
        name = 'atual',
        showlegend=True,
        legendgroup= 'atual',
        marker_color='CornflowerBlue'
    ), row=2, col=1)

fig.add_trace(
    go.Scatter(
        x=base.shift(30).dropna()['hospitalizados_enf'].ewm(span=13, adjust=False).mean().index,
        y=base.shift(30).dropna()['hospitalizados_enf'].ewm(span=13, adjust=False).mean(),
        name = 'Há 30 dias',
        showlegend=False,
        legendgroup= '30d',
        line=dict(color='darkorange'),
    ), row=2, col=1)

fig.add_trace(
    go.Bar(
        x=base['total_hospitalizados'].loc[base['total_hospitalizados'].shift(30).dropna().index].ewm(span=13, adjust=False).mean().index,
        y=base['total_hospitalizados'].loc[base['total_hospitalizados'].shift(30).dropna().index].ewm(span=13, adjust=False).mean(),
        name = 'atual',
        showlegend=False,
        legendgroup= 'atual',
        marker_color='CornflowerBlue'
    ), row=1, col=1)

fig.add_trace(
    go.Bar(
        x=base['hospitalizados_uti'].loc[base['hospitalizados_uti'].shift(30).dropna().index].ewm(span=13, adjust=False).mean().index,
        y=base['hospitalizados_uti'].loc[base['hospitalizados_uti'].shift(30).dropna().index].ewm(span=13, adjust=False).mean(),
        name = 'atual',
        showlegend=False,
        legendgroup= 'atual',
        marker_color='CornflowerBlue'
    ), row=3, col=1)

fig.add_trace(
    go.Scatter(
        x=base.shift(30).dropna()['hospitalizados_uti'].ewm(span=13, adjust=False).mean().index,
        y=base.shift(30).dropna()['hospitalizados_uti'].ewm(span=13, adjust=False).mean(),
        name = 'Há 30 dias',
        showlegend=False,
        legendgroup= '30d',
        line=dict(color='darkorange'),
    ), row=3, col=1)

fig.update_layout(
    template="plotly_white",
    
    legend_orientation="h",
    legend=dict(x=0, y=-.2),
    width=800,
    height=800,
    font=dict(
        family="Times New Roman",
        size=13,
        color="DimGray"
    )
)

fig.update_yaxes(title_text=" ", row=1, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_yaxes(title_text=" ", row=2, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_yaxes(title_text=" ", row=3, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_xaxes(title_text=" ", row=1, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_xaxes(title_text=" ", row=2, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_xaxes(title_text=" ", row=3, col=1,showgrid=False, showline=True, showticklabels=True)

fig.show()
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/30_dias.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1f2da473-4e23-495d-a94d-df992e20e8db" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f2da473-4e23-495d-a94d-df992e20e8db")) {                    Plotly.newPlot(                        "1f2da473-4e23-495d-a94d-df992e20e8db",                        [{"legendgroup":"30d","line":{"color":"darkorange"},"name":"H\u00e1 30 dias","showlegend":true,"x":["2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-08T00:00:00","2020-08-09T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-15T00:00:00","2020-08-16T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-22T00:00:00","2020-08-23T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-29T00:00:00","2020-08-30T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-19T00:00:00","2020-09-20T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-26T00:00:00","2020-09-27T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-02T00:00:00","2020-10-03T00:00:00","2020-10-04T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-10T00:00:00","2020-10-11T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-17T00:00:00","2020-10-18T00:00:00","2020-10-19T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T00:00:00","2020-10-24T00:00:00","2020-10-25T00:00:00","2020-10-26T00:00:00","2020-10-27T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-10-30T00:00:00","2020-10-31T00:00:00","2020-11-01T00:00:00","2020-11-02T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-05T00:00:00","2020-11- ...

# %%
fig = make_subplots(rows=2, cols=1, 
                    start_cell="bottom-left",
                   subplot_titles=('UTIs adicionadas','Enfermarias adicionadas')
                   ) #calcula a adicao de leitos, não há um df para isso.

fig.add_trace(go.Scatter(
    x=base['qnt_uti'].diff().cumsum().dropna().index,
    y=base['qnt_uti'].diff().cumsum().dropna(), #calculou-se da seguinte forma:
                                                    #1º calculou a variação de leitos existentes
                                        #2º fez a soma acumulada dessa variação, formando a evolução da adição dos leitos
    line=dict(color='DarkOrange'),
    name= 'UTIs',
    showlegend=True,
    legendgroup= 'UTIs',
), row=1, col=1)

fig.add_trace(go.Scatter(
    x=base['qnt_enf'].diff().cumsum().dropna().index,
    y=base['qnt_enf'].diff().cumsum().dropna(),
    line=dict(color='CornflowerBlue'),
    name= 'Enfermarias',
    showlegend=True,
    legendgroup= 'Enfermarias',
), row=2, col=1)


fig.update_layout(
    template="plotly_white",
    legend_orientation="h",
    legend=dict(x=0, y=-.1),
    width=800,
    height=600,
    font=dict(
        family="Times New Roman",
        size=13,
        color="DimGray"
    )
)

fig.update_yaxes(title_text="Leitos Adicionados" , nticks=10,  row=1, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_yaxes(title_text="Leitos Adicionados" , nticks=10, row=2, col=1,showgrid=False, showline=True, showticklabels=True)

fig.update_xaxes( nticks=20,  row=1, col=1,showgrid=False, showline=True, showticklabels=True)
fig.update_xaxes( nticks=20, row=2, col=1,showgrid=False, showline=True, showticklabels=True)


fig.show() #
fig.write_image('/content/drive/MyDrive/Labimec/BOLETIM COVID 2.0/Imagens/leitos_adic.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2ea28ef0-e166-49dd-9110-e32bc0ce096b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ea28ef0-e166-49dd-9110-e32bc0ce096b")) {                    Plotly.newPlot(                        "2ea28ef0-e166-49dd-9110-e32bc0ce096b",                        [{"legendgroup":"UTIs","line":{"color":"DarkOrange"},"name":"UTIs","showlegend":true,"x":["2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-08T00:00:00","2020-08-09T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-15T00:00:00","2020-08-16T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-22T00:00:00","2020-08-23T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-29T00:00:00","2020-08-30T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-19T00:00:00","2020-09-20T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-26T00:00:00","2020-09-27T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-02T00:00:00","2020-10-03T00:00:00","2020-10-04T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:0 ...
